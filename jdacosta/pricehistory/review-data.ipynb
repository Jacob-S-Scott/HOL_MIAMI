# %% [markdown]
# # Stock Price Data Upload to Snowflake
#
# This notebook demonstrates an **idempotent** upload process that:
#
# 1. ✅ Reads parquet files with stock price data
# 2. ✅ Connects to Snowflake using environment variables
# 3. ✅ Creates target table if it doesn't exist (never drops!)
# 4. ✅ Stages data to a temporary table
# 5. ✅ Uses MERGE to insert new records or update existing ones
# 6. ✅ Handles date columns properly (DATE as date, TIMESTAMP as timestamp)
# 7. ✅ Can be re-run multiple times without creating duplicates
#
# **Key Features:**
# - **Idempotent**: Safe to run multiple times
# - **No data loss**: Never drops or truncates tables
# - **Upsert logic**: Updates existing records, inserts new ones
# - **Proper date handling**: DATE columns stored as DATE type in Snowflake
#
# **Target Table:** `SNOWFLAKE_INTELLIGENCE_HOL.DATA.STOCK_PRICE_HISTORY`

# %%
import os
import logging
import time
from datetime import datetime, timedelta
from pathlib import Path
from typing import List, Optional, Dict, Any
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd
import yfinance as yf
import pyarrow as pa
import pyarrow.parquet as pq

# %%
ticker = "NVDA"
file = f"/Users/jdacosta/Library/CloudStorage/GoogleDrive-john.dacosta@snowflake.com/My Drive/_local/Downloads/_cursor_demos/Snowflake_Intelligence_HOL/jdacosta/pricehistory/data/price-history/{ticker}/price-history-{ticker}.parquet"

# %%
df = pd.read_parquet(file)

# %%
# Import Snowflake connection utilities
from snowflake_connection import SnowflakeConnectionManager
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()
# Out:
# True

# %%
df.head(10)
# Out:
#                        DATE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0 1999-01-22 00:00:00-05:00    0.040114    0.044770   0.035577     0.037607
# 1 1999-01-25 00:00:00-05:00    0.040591    0.042024   0.037607     0.041547
# 2 1999-01-26 00:00:00-05:00    0.042024    0.042860   0.037726     0.038323
# 3 1999-01-27 00:00:00-05:00    0.038442    0.039398   0.036293     0.038204
# 4 1999-01-28 00:00:00-05:00    0.038204    0.038442   0.037845     0.038084
# 5 1999-01-29 00:00:00-05:00    0.038084    0.038204   0.036293     0.036293
# 6 1999-02-01 00:00:00-05:00    0.036293    0.037248   0.036293     0.037010
# 7 1999-02-02 00:00:00-05:00    0.036293    0.037248   0.033070     0.034145
# 8 1999-02-03 00:00:00-05:00    0.033667    0.035339   0.033428     0.034861
# 9 1999-02-04 00:00:00-05:00    0.035339    0.037726   0.034861     0.036771
#
#        VOLUME  DIVIDENDS  STOCK_SPLITS TICKER         DOWNLOAD_TIMESTAMP
# 0  2714688000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 1   510480000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 2   343200000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 3   244368000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 4   227520000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 5   244032000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 6   154704000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 7   264096000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 8    75120000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 9   181920000        0.0           0.0   NVDA 2025-10-06 15:16:48.386646

# %%
df.tail(10)
# Out:
#                           DATE  OPEN_PRICE  HIGH_PRICE   LOW_PRICE  \
# 6707 2025-09-22 00:00:00-04:00  175.300003  184.550003  174.710007
# 6708 2025-09-23 00:00:00-04:00  181.970001  182.419998  176.210007
# 6709 2025-09-24 00:00:00-04:00  179.770004  179.779999  175.399994
# 6710 2025-09-25 00:00:00-04:00  174.479996  180.259995  173.130005
# 6711 2025-09-26 00:00:00-04:00  178.169998  179.770004  174.929993
# 6712 2025-09-29 00:00:00-04:00  180.429993  184.000000  180.320007
# 6713 2025-09-30 00:00:00-04:00  182.080002  187.350006  181.479996
# 6714 2025-10-01 00:00:00-04:00  185.240005  188.139999  183.899994
# 6715 2025-10-02 00:00:00-04:00  189.600006  191.050003  188.059998
# 6716 2025-10-03 00:00:00-04:00  189.190002  190.360001  185.380005
#
#       CLOSE_PRICE     VOLUME  DIVIDENDS  STOCK_SPLITS TICKER  \
# 6707   183.610001  269637000        0.0           0.0   NVDA
# 6708   178.429993  192559600        0.0           0.0   NVDA
# 6709   176.970001  143564100        0.0           0.0   NVDA
# 6710   177.690002  191586700        0.0           0.0   NVDA
# 6711   178.190002  148573700        0.0           0.0   NVDA
# 6712   181.850006  193063500        0.0           0.0   NVDA
# 6713   186.580002  236981000        0.0           0.0   NVDA
# 6714   187.240005  173844900        0.0           0.0   NVDA
# 6715   188.889999  136805800        0.0           0.0   NVDA
# 6716   187.619995  137340500        0.0           0.0   NVDA
#
#              DOWNLOAD_TIMESTAMP
# 6707 2025-10-06 15:16:48.386646
# 6708 2025-10-06 15:16:48.386646
# 6709 2025-10-06 15:16:48.386646
# 6710 2025-10-06 15:16:48.386646
# 6711 2025-10-06 15:16:48.386646
# 6712 2025-10-06 15:16:48.386646
# 6713 2025-10-06 15:16:48.386646
# 6714 2025-10-06 15:16:48.386646
# 6715 2025-10-06 15:16:48.386646
# 6716 2025-10-06 15:16:48.386646

# %%
# Check data info and date column type
print("DataFrame Info:")
print(f"Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"\nDate column dtype: {df['DATE'].dtype}")
print(f"Date range: {df['DATE'].min()} to {df['DATE'].max()}")
print(f"Duplicates: {df.duplicated(subset=['TICKER', 'DATE']).sum()}")
# Out:
# DataFrame Info:
# Shape: (6717, 10)
# Columns: ['DATE', 'OPEN_PRICE', 'HIGH_PRICE', 'LOW_PRICE', 'CLOSE_PRICE', 'VOLUME', 'DIVIDENDS', 'STOCK_SPLITS', 'TICKER', 'DOWNLOAD_TIMESTAMP']
#
# Date column dtype: datetime64[ns, America/New_York]
# Date range: 1999-01-22 00:00:00-05:00 to 2025-10-03 00:00:00-04:00
# Duplicates: 0

# %%
# Prepare data for Snowflake - ensure DATE is proper date type
df_upload = df.copy()

# Convert DATE column to date (remove time and timezone)
df_upload['DATE'] = pd.to_datetime(df_upload['DATE']).dt.date

# Convert DOWNLOAD_TIMESTAMP to timestamp without timezone
df_upload['DOWNLOAD_TIMESTAMP'] = pd.to_datetime(df_upload['DOWNLOAD_TIMESTAMP']).dt.tz_localize(None)

print("Data prepared for upload:")
print(f"DATE dtype: {df_upload['DATE'].dtype}")
print(f"DOWNLOAD_TIMESTAMP dtype: {df_upload['DOWNLOAD_TIMESTAMP'].dtype}")
df_upload.head(3)
# Out:
# Data prepared for upload:
# DATE dtype: object
# DOWNLOAD_TIMESTAMP dtype: datetime64[us]
#          DATE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE      VOLUME  \
# 0  1999-01-22    0.040114    0.044770   0.035577     0.037607  2714688000
# 1  1999-01-25    0.040591    0.042024   0.037607     0.041547   510480000
# 2  1999-01-26    0.042024    0.042860   0.037726     0.038323   343200000
#
#    DIVIDENDS  STOCK_SPLITS TICKER         DOWNLOAD_TIMESTAMP
# 0        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 1        0.0           0.0   NVDA 2025-10-06 15:16:48.386646
# 2        0.0           0.0   NVDA 2025-10-06 15:16:48.386646

# %%
# Connect to Snowflake
manager = SnowflakeConnectionManager()

try:
    session = manager.connect()
    print("✓ Connected to Snowflake")
    print(f"  Database: {session.get_current_database()}")
    print(f"  Schema: {session.get_current_schema()}")
    print(f"  Warehouse: {session.get_current_warehouse()}")
except Exception as e:
    print(f"✗ Connection failed: {e}")
    raise
# Out:
# ✓ Connected to Snowflake
#   Database: "SNOWFLAKE_INTELIGENCE_HOL"
#   Schema: "DATA"
#   Warehouse: "COMPUTE_WH"

# %%
# Create or verify main table exists (idempotent - never drops)
# Use the actual database and schema from the connection
current_database = session.get_current_database()
current_schema = session.get_current_schema()
table_name = "STOCK_PRICE_HISTORY"
target_table = f"{current_database}.{current_schema}.{table_name}"

print(f"Target table: {target_table}")

create_table_sql = f"""
CREATE TABLE IF NOT EXISTS {target_table} (
    DATE DATE,
    OPEN_PRICE FLOAT,
    HIGH_PRICE FLOAT,
    LOW_PRICE FLOAT,
    CLOSE_PRICE FLOAT,
    VOLUME NUMBER,
    DIVIDENDS FLOAT,
    STOCK_SPLITS FLOAT,
    TICKER VARCHAR(10),
    DOWNLOAD_TIMESTAMP TIMESTAMP,
    PRIMARY KEY (TICKER, DATE)
)
"""

try:
    session.sql(create_table_sql).collect()
    print(f"✓ Table {target_table} ready")
except Exception as e:
    print(f"✗ Failed to create table: {e}")
    raise
# Out:
# Target table: "SNOWFLAKE_INTELIGENCE_HOL"."DATA".STOCK_PRICE_HISTORY
# ✓ Table "SNOWFLAKE_INTELIGENCE_HOL"."DATA".STOCK_PRICE_HISTORY ready

# %%
# Create temporary staging table
temp_table = f"{target_table}_TEMP_{ticker}"

# Drop temp table if it exists (from previous runs)
session.sql(f"DROP TABLE IF EXISTS {temp_table}").collect()
print(f"✓ Cleaned up any existing temp table")

# Upload data to temporary table
try:
    # Convert pandas to Snowpark DataFrame
    snowpark_df = session.create_dataframe(df_upload)
    
    # Save to temp table
    snowpark_df.write.mode("overwrite").save_as_table(temp_table)
    
    # Get count
    temp_count = session.sql(f"SELECT COUNT(*) as cnt FROM {temp_table}").collect()[0]['CNT']
    print(f"✓ Staged {temp_count:,} records to {temp_table}")
    
except Exception as e:
    print(f"✗ Failed to stage data: {e}")
    raise
# Out:
# ✓ Cleaned up any existing temp table
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 11
#       8 # Upload data to temporary table
#       9 try:
#      10     # Convert pandas to Snowpark DataFrame
# ---> 11     snowpark_df = session.create_dataframe(df_upload)
#      13     # Save to temp table
#      14     snowpark_df.write.mode("overwrite").save_as_table(temp_table)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/snowpark/_internal/utils.py:1112, in publicapi.<locals>.call_wrapper(*args, **kwargs)
#    1108 kwargs["_emit_ast"] = is_ast_enabled()
#    1110 # TODO: Could modify internal docstring to display that users should not modify the _emit_ast parameter.
# -> 1112 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/snowpark/session.py:3477, in Session.create_dataframe(self, data, schema, _emit_ast)
#    3475     set_api_call_source(table, "Session.create_dataframe[arrow]")
#    3476 else:
# -> 3477     table = self.write_pandas(
#    3478         data,
#    3479         temp_table_name,
#    3480         database=sf_database,
#    3481         schema=sf_schema,
#    3482         quote_identifiers=True,
#    3483         auto_create_table=True,
#    3484         table_type="temporary",
#    3485         use_logical_type=self._use_logical_type_for_create_df,
#    3486         _emit_ast=False,
#    3487     )
#    3488     set_api_call_source(table, "Session.create_dataframe[pandas]")
#    3490 if _emit_ast:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/snowpark/_internal/utils.py:1106, in publicapi.<locals>.call_wrapper(*args, **kwargs)
#    1102     return func(*args, **kwargs)
#    1104 if "_emit_ast" in kwargs:
#    1105     # The caller provided _emit_ast explicitly.
# -> 1106     return func(*args, **kwargs)
#    1108 kwargs["_emit_ast"] = is_ast_enabled()
#    1110 # TODO: Could modify internal docstring to display that users should not modify the _emit_ast parameter.
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/snowpark/session.py:3270, in Session.write_pandas(self, df, table_name, database, schema, chunk_size, compression, on_error, parallel, quote_identifiers, auto_create_table, create_temp_table, overwrite, table_type, use_logical_type, _emit_ast, **kwargs)
#    3268             success, ci_output = True, []
#    3269         else:
# -> 3270             success, _, _, ci_output = write_pandas(
#    3271                 self._conn._conn,
#    3272                 df,
#    3273                 table_name,
#    3274                 database=database,
#    3275                 schema=schema,
#    3276                 chunk_size=chunk_size,
#    3277                 compression=compression,
#    3278                 on_error=on_error,
#    3279                 parallel=parallel,
#    3280                 quote_identifiers=quote_identifiers,
#    3281                 auto_create_table=auto_create_table,
#    3282                 overwrite=overwrite,
#    3283                 table_type=table_type,
#    3284                 **kwargs,
#    3285             )
#    3286 except ProgrammingError as pe:
#    3287     if pe.msg.endswith("does not exist"):
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/pandas_tools.py:600, in write_pandas(conn, df, table_name, database, schema, chunk_size, compression, on_error, parallel, quote_identifiers, auto_create_table, create_temp_table, overwrite, table_type, use_logical_type, iceberg_config, bulk_upload_chunks, **kwargs)
#     595 params = (
#     596     target_table_location,
#     597     on_error,
#     598 )
#     599 logger.debug(f"copying into with '{copy_into_sql}'. params: %s", params)
# --> 600 copy_results = cursor.execute(
#     601     copy_into_sql,
#     602     _is_internal=True,
#     603     _force_qmark_paramstyle=True,
#     604     params=params,
#     605     num_statements=1,
#     606 ).fetchall()
#     608 if overwrite and auto_create_table:
#     609     original_table_location = build_location_helper(
#     610         database=database,
#     611         schema=schema,
#     612         name=table_name,
#     613         quote_identifiers=quote_identifiers,
#     614     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/cursor.py:1019, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1012     logger.debug(
#    1013         "query was rewritten: org=%s, new=%s",
#    1014         " ".join(line.strip() for line in query.split("\n")),
#    1015         query1,
#    1016     )
#    1017     query = query1
# -> 1019 ret = self._execute_helper(query, **kwargs)
#    1020 self._sfqid = (
#    1021     ret["data"]["queryId"]
#    1022     if "data" in ret and "queryId" in ret["data"]
#    1023     else None
#    1024 )
#    1025 logger.debug(f"sfqid: {self.sfqid}")
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/cursor.py:725, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get, _no_retry, dataframe_ast)
#     723 ret: dict[str, Any] = {"data": {}}
#     724 try:
# --> 725     ret = self._connection.cmd_query(
#     726         query,
#     727         self._sequence_counter,
#     728         self._request_id,
#     729         binding_params=binding_params,
#     730         binding_stage=binding_stage,
#     731         is_file_transfer=bool(self._is_file_transfer),
#     732         statement_params=statement_params,
#     733         is_internal=is_internal,
#     734         describe_only=describe_only,
#     735         _no_results=_no_results,
#     736         _no_retry=_no_retry,
#     737         timeout=real_timeout,
#     738         dataframe_ast=dataframe_ast,
#     739     )
#     740 finally:
#     741     try:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/connection.py:1601, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object, _no_retry, timeout, dataframe_ast)
#    1592     logger.debug(
#    1593         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#    1594         self._format_query_for_log(data["sqlText"]),
#    1595         data["sequenceId"],
#    1596         is_file_transfer,
#    1597     )
#    1599 url_parameters = {REQUEST_ID: request_id}
# -> 1601 ret = self.rest.request(
#    1602     "/queries/v1/query-request?" + urlencode(url_parameters),
#    1603     data,
#    1604     client=client,
#    1605     _no_results=_no_results,
#    1606     _include_retry_params=True,
#    1607     _no_retry=_no_retry,
#    1608     timeout=timeout,
#    1609 )
#    1611 if ret is None:
#    1612     ret = {"data": {}}
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/network.py:538, in SnowflakeRestful.request(self, url, body, method, client, timeout, _no_results, _include_retry_params, _no_retry)
#     536     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     537 if method == "post":
# --> 538     return self._post_request(
#     539         url,
#     540         headers,
#     541         json.dumps(body, cls=SnowflakeRestfulJsonEncoder),
#     542         token=self.token,
#     543         external_session_id=self.external_session_id,
#     544         _no_results=_no_results,
#     545         timeout=timeout,
#     546         _include_retry_params=_include_retry_params,
#     547         no_retry=_no_retry,
#     548     )
#     549 else:
#     550     return self._get_request(
#     551         url,
#     552         headers,
#    (...)
#     555         timeout=timeout,
#     556     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/network.py:805, in SnowflakeRestful._post_request(self, url, headers, body, token, external_session_id, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     802     ret = probe_connection(full_url)
#     803     pprint(ret)
# --> 805 ret = self.fetch(
#     806     "post",
#     807     full_url,
#     808     headers,
#     809     data=body,
#     810     timeout=timeout,
#     811     token=token,
#     812     external_session_id=external_session_id,
#     813     no_retry=no_retry,
#     814     _include_retry_params=_include_retry_params,
#     815     socket_timeout=socket_timeout,
#     816 )
#     817 logger.debug(
#     818     "ret[code] = {code}, after post request".format(
#     819         code=(ret.get("code", "N/A"))
#     820     )
#     821 )
#     823 if ret.get("code") == MASTER_TOKEN_EXPIRED_GS_CODE:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/network.py:924, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     922 retry_ctx.set_start_time()
#     923 while True:
# --> 924     ret = self._request_exec_wrapper(
#     925         session, method, full_url, headers, data, retry_ctx, **kwargs
#     926     )
#     927     if ret is not None:
#     928         return ret
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/network.py:975, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, external_session_id, **kwargs)
#     973 raise_raw_http_failure = kwargs.pop("raise_raw_http_failure", False)
#     974 try:
# --> 975     return_object = self._request_exec(
#     976         session=session,
#     977         method=method,
#     978         full_url=full_url,
#     979         headers=headers,
#     980         data=data,
#     981         token=token,
#     982         external_session_id=external_session_id,
#     983         raise_raw_http_failure=raise_raw_http_failure,
#     984         **kwargs,
#     985     )
#     986     if return_object is not None:
#     987         return return_object
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/network.py:1149, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, external_session_id, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1141 # socket timeout is constant. You should be able to receive
#    1142 # the response within the time. If not, ConnectReadTimeout or
#    1143 # ReadTimeout is raised.
#    1144 auth = (
#    1145     PATWithExternalSessionAuth(token, external_session_id)
#    1146     if (external_session_id is not None and token is not None)
#    1147     else SnowflakeAuth(token)
#    1148 )
# -> 1149 raw_ret = session.request(
#    1150     method=method,
#    1151     url=full_url,
#    1152     headers=headers,
#    1153     data=input_data,
#    1154     timeout=socket_timeout,
#    1155     verify=True,
#    1156     stream=is_raw_binary,
#    1157     auth=auth,
#    1158 )
#    1159 download_end_time = get_time_millis()
#    1161 try:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/requests/adapters.py:485, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     482     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     484 try:
# --> 485     resp = conn.urlopen(
#     486         method=request.method,
#     487         url=url,
#     488         body=request.body,
#     489         headers=request.headers,
#     490         redirect=False,
#     491         assert_same_host=False,
#     492         preload_content=False,
#     493         decode_content=False,
#     494         retries=self.max_retries,
#     495         timeout=timeout,
#     496         chunked=chunked,
#     497     )
#     499 except (ProtocolError, OSError) as err:
#     500     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/contrib/pyopenssl.py:330, in WrappedSocket.recv_into(self, *args, **kwargs)
#     328         raise
#     329 except OpenSSL.SSL.WantReadError:
# --> 330     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     331         raise timeout("The read operation timed out")
#     332     else:
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:145, in wait_for_read(sock, timeout)
#     141 def wait_for_read(sock, timeout=None):
#     142     """Waits for reading to be available on a given socket.
#     143     Returns True if the socket is readable, or False if the timeout expired.
#     144     """
# --> 145     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:106, in poll_wait_for_socket(sock, read, write, timeout)
#     103         t *= 1000
#     104     return poll_obj.poll(t)
# --> 106 return bool(_retry_on_intr(do_poll, timeout))
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:104, in poll_wait_for_socket.<locals>.do_poll(t)
#     102 if t is not None:
#     103     t *= 1000
# --> 104 return poll_obj.poll(t)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/snowflake/connector/cursor.py:714, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     711         except (ValueError, TypeError):
#     712             # ignore failures
#     713             pass
# --> 714 raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %%
# Check current state of target table
try:
    existing_count_result = session.sql(f"""
        SELECT COUNT(*) as cnt 
        FROM {target_table}
        WHERE TICKER = '{ticker}'
    """).collect()
    
    existing_count = existing_count_result[0]['CNT'] if existing_count_result else 0
    print(f"Existing records for {ticker}: {existing_count:,}")
except Exception as e:
    # Table might be empty or not exist yet
    existing_count = 0
    print(f"No existing records for {ticker}")
# Out:
# Existing records for NVDA: 0

# %%
# Perform idempotent MERGE (upsert)
# This will INSERT new records and UPDATE existing ones based on (TICKER, DATE)
merge_sql = f"""
MERGE INTO {target_table} AS target
USING {temp_table} AS source
ON target.TICKER = source.TICKER 
   AND target.DATE = source.DATE
WHEN MATCHED THEN
    UPDATE SET
        target.OPEN_PRICE = source.OPEN_PRICE,
        target.HIGH_PRICE = source.HIGH_PRICE,
        target.LOW_PRICE = source.LOW_PRICE,
        target.CLOSE_PRICE = source.CLOSE_PRICE,
        target.VOLUME = source.VOLUME,
        target.DIVIDENDS = source.DIVIDENDS,
        target.STOCK_SPLITS = source.STOCK_SPLITS,
        target.DOWNLOAD_TIMESTAMP = source.DOWNLOAD_TIMESTAMP
WHEN NOT MATCHED THEN
    INSERT (
        DATE, OPEN_PRICE, HIGH_PRICE, LOW_PRICE, CLOSE_PRICE,
        VOLUME, DIVIDENDS, STOCK_SPLITS, TICKER, DOWNLOAD_TIMESTAMP
    )
    VALUES (
        source.DATE, source.OPEN_PRICE, source.HIGH_PRICE, source.LOW_PRICE, source.CLOSE_PRICE,
        source.VOLUME, source.DIVIDENDS, source.STOCK_SPLITS, source.TICKER, source.DOWNLOAD_TIMESTAMP
    )
"""

try:
    merge_result = session.sql(merge_sql).collect()
    print("✓ MERGE completed successfully")
    
    # Get updated count
    final_count_result = session.sql(f"""
        SELECT COUNT(*) as cnt 
        FROM {target_table}
        WHERE TICKER = '{ticker}'
    """).collect()
    
    final_count = final_count_result[0]['CNT']
    new_records = final_count - existing_count
    
    print(f"\nResults:")
    print(f"  Previous count: {existing_count:,}")
    print(f"  Final count: {final_count:,}")
    print(f"  New/Updated records: {new_records:,}")
    
except Exception as e:
    print(f"✗ MERGE failed: {e}")
    raise
# Out:
# ✓ MERGE completed successfully
#
# Results:
#   Previous count: 0
#   Final count: 6,717
#   New/Updated records: 6,717

# %%
# Cleanup: Drop temporary table
try:
    session.sql(f"DROP TABLE IF EXISTS {temp_table}").collect()
    print(f"✓ Cleaned up temp table {temp_table}")
except Exception as e:
    print(f"⚠ Warning: Could not drop temp table: {e}")
# Out:
# ✓ Cleaned up temp table "SNOWFLAKE_INTELIGENCE_HOL"."DATA".STOCK_PRICE_HISTORY_TEMP_NVDA

# %%
# Verify the data in Snowflake
verify_sql = f"""
SELECT 
    TICKER,
    MIN(DATE) as MIN_DATE,
    MAX(DATE) as MAX_DATE,
    COUNT(*) as TOTAL_RECORDS,
    MIN(CLOSE_PRICE) as MIN_PRICE,
    MAX(CLOSE_PRICE) as MAX_PRICE
FROM {target_table}
WHERE TICKER = '{ticker}'
GROUP BY TICKER
"""

result_df = session.sql(verify_sql).to_pandas()
print("\n" + "="*60)
print("VERIFICATION - Data in Snowflake:")
print("="*60)
print(result_df.to_string(index=False))

# Show sample of latest records
sample_sql = f"""
SELECT DATE, OPEN_PRICE, HIGH_PRICE, LOW_PRICE, CLOSE_PRICE, VOLUME, TICKER
FROM {target_table}
WHERE TICKER = '{ticker}'
ORDER BY DATE DESC
LIMIT 5
"""

sample_df = session.sql(sample_sql).to_pandas()
print("\n" + "="*60)
print("Latest 5 records in Snowflake:")
print("="*60)
print(sample_df.to_string(index=False))
# Out:
# ============================================================
# VERIFICATION - Data in Snowflake:
# ============================================================
# TICKER   MIN_DATE   MAX_DATE  TOTAL_RECORDS  MIN_PRICE  MAX_PRICE
#   NVDA 1999-01-22 2025-10-03           6717    0.03128 188.889999
#
# ============================================================
# Latest 5 records in Snowflake:
# ============================================================
#       DATE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE    VOLUME TICKER
# 2025-10-03  189.190002  190.360001 185.380005   187.619995 137340500   NVDA
# 2025-10-02  189.600006  191.050003 188.059998   188.889999 136805800   NVDA
# 2025-10-01  185.240005  188.139999 183.899994   187.240005 173844900   NVDA
# 2025-09-30  182.080002  187.350006 181.479996   186.580002 236981000   NVDA
# 2025-09-29  180.429993  184.000000 180.320007   181.850006 193063500   NVDA

# %%
# Close Snowflake connection
manager.close()
print("\n✓ Snowflake session closed")
print("\n" + "="*60)
print("UPLOAD COMPLETE - Process is idempotent and can be re-run safely!")
print("="*60)
# Out:
# ✓ Snowflake session closed
#
# ============================================================
# UPLOAD COMPLETE - Process is idempotent and can be re-run safely!
# ============================================================
